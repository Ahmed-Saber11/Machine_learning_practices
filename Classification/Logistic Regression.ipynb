# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('advertising.csv')

# %%
data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# 1  2016-04-04 01:39:02              0
# 2  2016-03-13 20:35:42              0
# 3  2016-01-10 02:31:19              0
# 4  2016-06-03 03:36:18              0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.3+ KB

# %%
data.describe().round()
# Out:
#        Daily Time Spent on Site     Age  Area Income  Daily Internet Usage  \
# count                    1000.0  1000.0       1000.0                1000.0
# mean                       65.0    36.0      55000.0                 180.0
# std                        16.0     9.0      13415.0                  44.0
# min                        33.0    19.0      13996.0                 105.0
# 25%                        51.0    29.0      47032.0                 139.0
# 50%                        68.0    35.0      57012.0                 183.0
# 75%                        79.0    42.0      65471.0                 219.0
# max                        91.0    61.0      79485.0                 270.0
#
#          Male  Clicked on Ad
# count  1000.0         1000.0
# mean      0.0            0.0
# std       0.0            1.0
# min       0.0            0.0
# 25%       0.0            0.0
# 50%       0.0            0.0
# 75%       1.0            1.0
# max       1.0            1.0

# %%
data.describe(include = 'object')
# Out:
#                              Ad Topic Line       City Country  \
# count                                 1000       1000    1000
# unique                                1000        969     237
# top     Cloned 5thgeneration orchestration  Lisamouth  France
# freq                                     1          3       9
#
#                   Timestamp
# count                  1000
# unique                 1000
# top     2016-03-27 00:53:11
# freq                      1

# %%
data.drop(['Ad Topic Line', 'City', 'Timestamp'], axis= 1, inplace= True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# Daily Time Spent on Site    0
# Age                         0
# Area Income                 0
# Daily Internet Usage        0
# Male                        0
# Country                     0
# Clicked on Ad               0
# dtype: int64

# %% [markdown]
# ## Preprocessing

# %%
# define features and Target
x = data.drop('Clicked on Ad',axis = 1)
y = data['Clicked on Ad']

# %%
x
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male  \
# 0                       68.95   35     61833.90                256.09     0
# 1                       80.23   31     68441.85                193.77     1
# 2                       69.47   26     59785.94                236.50     0
# 3                       74.15   29     54806.18                245.89     1
# 4                       68.37   35     73889.99                225.58     0
# ..                        ...  ...          ...                   ...   ...
# 995                     72.97   30     71384.57                208.58     1
# 996                     51.30   45     67782.17                134.42     1
# 997                     51.63   51     42415.72                120.37     1
# 998                     55.55   19     41920.79                187.95     0
# 999                     45.01   26     29875.80                178.35     0
#
#                     Country
# 0                   Tunisia
# 1                     Nauru
# 2                San Marino
# 3                     Italy
# 4                   Iceland
# ..                      ...
# 995                 Lebanon
# 996  Bosnia and Herzegovina
# 997                Mongolia
# 998               Guatemala
# 999                  Brazil
#
# [1000 rows x 6 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 995    1
# 996    1
# 997    1
# 998    0
# 999    1
# Name: Clicked on Ad, Length: 1000, dtype: int64

# %%
x.shape,y.shape
# Out:
# ((1000, 6), (1000,))

# %%
y.value_counts()
# balanced
# Out:
# Clicked on Ad
# 0    500
# 1    500
# Name: count, dtype: int64

# %%
# split data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2, random_state= 0, stratify= y)

# %% [markdown]
# ## Handle Numeric Features

# %%
scaling_cols = x_train.columns.drop(['Country', 'Male'])
scaling_cols
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage'],
#       dtype='object')

# %%
from sklearn.preprocessing import RobustScaler

rc = RobustScaler()

x_train[scaling_cols] = rc.fit_transform(x_train[scaling_cols])
x_test[scaling_cols] = rc.transform(x_test[scaling_cols])

# %%
x_train.head()
# Out:
#      Daily Time Spent on Site       Age  Area Income  Daily Internet Usage  \
# 600                  0.594840  1.083333    -0.569248             -0.580319
# 737                  0.120824  1.416667    -0.863072             -0.750515
# 33                  -0.459354 -1.000000    -1.483623              0.374008
# 519                 -1.224016  0.416667    -0.615119             -0.392377
# 341                  0.157944  1.083333    -0.246821             -0.840987
#
#      Male          Country
# 600     1  Kyrgyz Republic
# 737     0           Sweden
# 33      0          Senegal
# 519     1         Mongolia
# 341     0           Mexico

# %% [markdown]
# ## Handle Categorical Features

# %%
from category_encoders import BinaryEncoder

be = BinaryEncoder()

be_train = be.fit_transform(x_train[['Country']])
be_test = be.transform(x_test[['Country']])

# %%
be_train
# Out:
#      Country_0  Country_1  Country_2  Country_3  Country_4  Country_5  \
# 600          0          0          0          0          0          0
# 737          0          0          0          0          0          0
# 33           0          0          0          0          0          0
# 519          0          0          0          0          0          1
# 341          0          0          0          0          0          1
# ..         ...        ...        ...        ...        ...        ...
# 622          1          1          0          0          1          1
# 682          0          0          0          1          1          1
# 357          0          0          1          0          0          1
# 918          1          1          0          1          0          1
# 342          1          0          0          1          1          1
#
#      Country_6  Country_7
# 600          0          1
# 737          1          0
# 33           1          1
# 519          0          0
# 341          0          1
# ..         ...        ...
# 622          0          1
# 682          0          1
# 357          1          0
# 918          0          0
# 342          1          0
#
# [800 rows x 8 columns]

# %%
x_train = pd.concat([x_train, be_train], axis= 1).drop('Country', axis = 1)

x_test = pd.concat([x_test, be_test], axis= 1).drop('Country', axis = 1)

# %%
x_train
# Out:
#      Daily Time Spent on Site       Age  Area Income  Daily Internet Usage  \
# 600                  0.594840  1.083333    -0.569248             -0.580319
# 737                  0.120824  1.416667    -0.863072             -0.750515
# 33                  -0.459354 -1.000000    -1.483623              0.374008
# 519                 -1.224016  0.416667    -0.615119             -0.392377
# 341                  0.157944  1.083333    -0.246821             -0.840987
# ..                        ...       ...          ...                   ...
# 622                 -0.287491  2.083333    -0.603832             -0.388754
# 682                 -0.905902  0.083333    -0.343783             -0.717901
# 357                 -0.673163  0.333333    -0.627936             -0.887973
# 918                  0.401448 -0.250000     0.609726              0.407873
# 342                  0.747773  0.250000    -0.581050              0.603062
#
#      Male  Country_0  Country_1  Country_2  Country_3  Country_4  Country_5  \
# 600     1          0          0          0          0          0          0
# 737     0          0          0          0          0          0          0
# 33      0          0          0          0          0          0          0
# 519     1          0          0          0          0          0          1
# 341     0          0          0          0          0          0          1
# ..    ...        ...        ...        ...        ...        ...        ...
# 622     1          1          1          0          0          1          1
# 682     1          0          0          0          1          1          1
# 357     0          0          0          1          0          0          1
# 918     1          1          1          0          1          0          1
# 342     0          1          0          0          1          1          1
#
#      Country_6  Country_7
# 600          0          1
# 737          1          0
# 33           1          1
# 519          0          0
# 341          0          1
# ..         ...        ...
# 622          0          1
# 682          0          1
# 357          1          0
# 918          0          0
# 342          1          0
#
# [800 rows x 13 columns]

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

LG = LogisticRegression(penalty= None)
LG.fit(x_train, y_train)

y_prd = LG.predict(x_test)

# %%
print('Train Accuracy :',LG.score(x_train, y_train) * 100)
print('Test Accuracy :',LG.score(x_test, y_test) * 100)
# Out:
# Train Accuracy : 97.375
# Test Accuracy : 95.0

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
# Precision: How many predicted positives are actually positive?
precision = precision_score(y_prd, y_test)

# Recall: How many actual positives were correctly predicted?
recall = recall_score(y_prd, y_test)

# F1 Score: Harmonic mean of precision and recall
f1 = f1_score(y_prd, y_test)

# Confusion Matrix: Shows TP, TN, FP, FN
cm = confusion_matrix(y_prd, y_test)

# %%
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Confusion Matrix:\n", cm)
# Out:
# Precision: 0.92
# Recall: 0.9787234042553191
# F1 Score: 0.9484536082474226
# Confusion Matrix:
#  [[98  8]
#  [ 2 92]]

# %%
cm
# Out:
# array([[98,  8],
#        [ 2, 92]], dtype=int64)
